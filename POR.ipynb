# %%
#CSS Cloud Service Server
#TPA Third Party Auditor

# %% [markdown]
# # Setup phase

# %% [markdown]
# #### client generates its public and private parameters by invoking GenKey

# %%
import string
import random
from math import sqrt 

# Returns True if n is prime  
def isPrime( n):  
  
    # Corner cases  
    if (n <= 1): 
        return False
    if (n <= 3): 
        return True
  
    # This is checked so that we can skip  
    # middle five numbers in below loop  
    if (n % 2 == 0 or n % 3 == 0): 
        return False
    i = 5
    while(i * i <= n): 
        if (n % i == 0 or n % (i + 2) == 0) : 
            return False
        i = i + 6
  
    return True
  
""" Iterative Function to calculate (x^n)%p 
    in O(logy) */"""
def power( x, y, p):  
  
    res = 1 # Initialize result  
  
    x = x % p # Update x if it is more  
              # than or equal to p  
  
    while (y > 0):  
  
        # If y is odd, multiply x with result  
        if (y & 1): 
            res = (res * x) % p  
  
        # y must be even now  
        y = y >> 1 # y = y/2  
        x = (x * x) % p  
  
    return res  
  
# Utility function to store prime 
# factors of a number  
def findPrimefactors(s, n) : 
  
    # Pr the number of 2s that divide n  
    while (n % 2 == 0) : 
        s.add(2)  
        n = n // 2
  
    # n must be odd at this po. So we can   
    # skip one element (Note i = i +2)  
    for i in range(3, int(sqrt(n)), 2): 
          
        # While i divides n, pr i and divide n  
        while (n % i == 0) : 
  
            s.add(i)  
            n = n // i  
          
    # This condition is to handle the case  
    # when n is a prime number greater than 2  
    if (n > 2) : 
        s.add(n)  

# Function to find smallest primitive
# root of n  
def findPrimitive( n) : 
    s = set()  
  
    # Check if n is prime or not  
    if (isPrime(n) == False):  
        return -1
  
    # Find value of Euler Totient function  
    # of n. Since n is a prime number, the  
    # value of Euler Totient function is n-1  
    # as there are n-1 relatively prime numbers. 
    phi = n - 1
  
    # Find prime factors of phi and store in a set  
    findPrimefactors(s, phi)  
  
    # Check for every number from 2 to phi  
    for r in range(2, phi + 1):  
  
        # Iterate through all prime factors of phi.  
        # and check if we found a power with value 1  
        flag = False
        for it in s:  
  
            # Check if r^((phi)/primefactors) 
            # mod n is 1 or not  
            if (power(r, phi // it, n) == 1):  
  
                flag = True
                break
              
        # If there was no power with value 1.  
        if (flag == False): 
            return r  
  
    # If no primitive root found  
    return -1

def key_generator(size=6, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.choice(chars) for _ in range(size))

def GenKey(k):
    q = 1000
    primes = [i for i in range(2,q) if isPrime(i)]
    n = random.choice(primes)
    g = findPrimitive(n)
    key_prp = key_generator()
    key_sym = key_generator()
    pk = random.choice([n, g])
    sk = random.choice([key_prp, key_sym])
    return pk, sk

# %%
pk, sk = GenKey(4)
print(pk)
print(sk)
# Out:
# 997
# SZA2U9

# %% [markdown]
# #### running Gen Watermark produces the verification watermark and the recovery watermark

# %%
import bitarray
import base64

# message = pk
# encoded_message = base64.b64encode(message)
# #Converts the message into an array of bits
# ba = bitarray.bitarray()
# ba.frombytes(encoded_message.encode('utf-8'))
# bit_array = [int(i) for i in ba]

from PIL import Image

def GenWatermark():
    im = Image.open("spongebob.png")
    width, height = im.size
    print('width = %d'%width)
    pixels = im.load()
    print(pixels)

    i = 0
    #for each row
    for h in range(0, height):
        h = 150
        # each pixel of the row h
        for w in range(0, width):
            r,g,b = pixels[w, h]
            print("[+] Pixel : [%d,%d]"%(w, h))
            # print("[+] \tBefore : (%d,%d,%d)"%(r,g,b))

            #Red pixel
            print('red_bit_decimal= %d'%r)
            r_bit = bin(r)[2:].zfill(8)
            print('red_bit_binary= %s'%r_bit)
            r_lsb_bit = r_bit[-2:]
            
            r_set_lsb_bit_to_0 = r_bit[:-2]+'00'
            new_red_pixel = int(r_set_lsb_bit_to_0, 2)
            print('red_bit_decimal_set_lsb= %d'%new_red_pixel)
            
            #Green pixel
            print('green_bit_decimal= %d'%g)
            g_bit = bin(g)[2:].zfill(8)
            print('green_bit_binary= %s'%g_bit)
            g_lsb_bit = g_bit[-2:]
            
            g_set_lsb_bit_to_0 = g_bit[:-2]+'00'
            new_green_pixel = int(g_set_lsb_bit_to_0, 2)
            print('green_bit_decimal_set_lsb= %d'%new_green_pixel)
            
            #Blue pixel
            print('blue_bit_decimal= %d'%b)
            b_bit = bin(b)[2:].zfill(8)
            print('blue_bit_binary= %s'%b_bit)
            b_lsb_bit = b_bit[-2:]
            
            b_set_lsb_bit_to_0 = b_bit[:-2]+'00'
            new_blue_pixel = int(b_set_lsb_bit_to_0, 2)
            print('blue_bit_decimal_set_lsb= %d'%new_blue_pixel)
            
            pixels[w, h] = (new_red_pixel, new_green_pixel, new_blue_pixel)
            
        if h == 150:
            break
    
    im.close()
    im.save('lsb_spongebob.png')

# %%
GenWatermark()
# Out:
# width = 391
# <PixelAccess object at 0x7f228f9eb890>
# [+] Pixel : [0,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [1,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [2,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [3,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [4,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [5,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [6,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [7,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [8,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [9,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [10,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [11,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [12,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [13,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [14,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [15,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [16,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [17,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [18,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [19,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [20,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [21,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [22,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [23,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [24,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [25,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [26,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [27,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [28,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [29,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [30,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 251
# blue_bit_binary= 11111011
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [31,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 248
# blue_bit_binary= 11111000
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [32,150]
# red_bit_decimal= 129
# red_bit_binary= 10000001
# red_bit_decimal_set_lsb= 128
# green_bit_decimal= 150
# green_bit_binary= 10010110
# green_bit_decimal_set_lsb= 148
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [33,150]
# red_bit_decimal= 124
# red_bit_binary= 01111100
# red_bit_decimal_set_lsb= 124
# green_bit_decimal= 143
# green_bit_binary= 10001111
# green_bit_decimal_set_lsb= 140
# blue_bit_decimal= 79
# blue_bit_binary= 01001111
# blue_bit_decimal_set_lsb= 76
# [+] Pixel : [34,150]
# red_bit_decimal= 124
# red_bit_binary= 01111100
# red_bit_decimal_set_lsb= 124
# green_bit_decimal= 138
# green_bit_binary= 10001010
# green_bit_decimal_set_lsb= 136
# blue_bit_decimal= 59
# blue_bit_binary= 00111011
# blue_bit_decimal_set_lsb= 56
# [+] Pixel : [35,150]
# red_bit_decimal= 141
# red_bit_binary= 10001101
# red_bit_decimal_set_lsb= 140
# green_bit_decimal= 148
# green_bit_binary= 10010100
# green_bit_decimal_set_lsb= 148
# blue_bit_decimal= 52
# blue_bit_binary= 00110100
# blue_bit_decimal_set_lsb= 52
# [+] Pixel : [36,150]
# red_bit_decimal= 151
# red_bit_binary= 10010111
# red_bit_decimal_set_lsb= 148
# green_bit_decimal= 147
# green_bit_binary= 10010011
# green_bit_decimal_set_lsb= 144
# blue_bit_decimal= 37
# blue_bit_binary= 00100101
# blue_bit_decimal_set_lsb= 36
# [+] Pixel : [37,150]
# red_bit_decimal= 212
# red_bit_binary= 11010100
# red_bit_decimal_set_lsb= 212
# green_bit_decimal= 196
# green_bit_binary= 11000100
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 75
# blue_bit_binary= 01001011
# blue_bit_decimal_set_lsb= 72
# [+] Pixel : [38,150]
# red_bit_decimal= 244
# red_bit_binary= 11110100
# red_bit_decimal_set_lsb= 244
# green_bit_decimal= 219
# green_bit_binary= 11011011
# green_bit_decimal_set_lsb= 216
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [39,150]
# red_bit_decimal= 248
# red_bit_binary= 11111000
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 219
# green_bit_binary= 11011011
# green_bit_decimal_set_lsb= 216
# blue_bit_decimal= 91
# blue_bit_binary= 01011011
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [40,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 227
# green_bit_binary= 11100011
# green_bit_decimal_set_lsb= 224
# blue_bit_decimal= 97
# blue_bit_binary= 01100001
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [41,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 228
# green_bit_binary= 11100100
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [42,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [43,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [44,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [45,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [46,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [47,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [48,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 231
# green_bit_binary= 11100111
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [49,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 231
# green_bit_binary= 11100111
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [50,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [51,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [52,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [53,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [54,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [55,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [56,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [57,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [58,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [59,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [60,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [61,150]
# red_bit_decimal= 252
# red_bit_binary= 11111100
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 228
# green_bit_binary= 11100100
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [62,150]
# red_bit_decimal= 250
# red_bit_binary= 11111010
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 226
# green_bit_binary= 11100010
# green_bit_decimal_set_lsb= 224
# blue_bit_decimal= 92
# blue_bit_binary= 01011100
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [63,150]
# red_bit_decimal= 248
# red_bit_binary= 11111000
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 224
# green_bit_binary= 11100000
# green_bit_decimal_set_lsb= 224
# blue_bit_decimal= 90
# blue_bit_binary= 01011010
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [64,150]
# red_bit_decimal= 247
# red_bit_binary= 11110111
# red_bit_decimal_set_lsb= 244
# green_bit_decimal= 225
# green_bit_binary= 11100001
# green_bit_decimal_set_lsb= 224
# blue_bit_decimal= 124
# blue_bit_binary= 01111100
# blue_bit_decimal_set_lsb= 124
# [+] Pixel : [65,150]
# red_bit_decimal= 234
# red_bit_binary= 11101010
# red_bit_decimal_set_lsb= 232
# green_bit_decimal= 215
# green_bit_binary= 11010111
# green_bit_decimal_set_lsb= 212
# blue_bit_decimal= 136
# blue_bit_binary= 10001000
# blue_bit_decimal_set_lsb= 136
# [+] Pixel : [66,150]
# red_bit_decimal= 122
# red_bit_binary= 01111010
# red_bit_decimal_set_lsb= 120
# green_bit_decimal= 110
# green_bit_binary= 01101110
# green_bit_decimal_set_lsb= 108
# blue_bit_decimal= 60
# blue_bit_binary= 00111100
# blue_bit_decimal_set_lsb= 60
# [+] Pixel : [67,150]
# red_bit_decimal= 21
# red_bit_binary= 00010101
# red_bit_decimal_set_lsb= 20
# green_bit_decimal= 14
# green_bit_binary= 00001110
# green_bit_decimal_set_lsb= 12
# blue_bit_decimal= 0
# blue_bit_binary= 00000000
# blue_bit_decimal_set_lsb= 0
# [+] Pixel : [68,150]
# red_bit_decimal= 19
# red_bit_binary= 00010011
# red_bit_decimal_set_lsb= 16
# green_bit_decimal= 15
# green_bit_binary= 00001111
# green_bit_decimal_set_lsb= 12
# blue_bit_decimal= 12
# blue_bit_binary= 00001100
# blue_bit_decimal_set_lsb= 12
# [+] Pixel : [69,150]
# red_bit_decimal= 5
# red_bit_binary= 00000101
# red_bit_decimal_set_lsb= 4
# green_bit_decimal= 5
# green_bit_binary= 00000101
# green_bit_decimal_set_lsb= 4
# blue_bit_decimal= 7
# blue_bit_binary= 00000111
# blue_bit_decimal_set_lsb= 4
# [+] Pixel : [70,150]
# red_bit_decimal= 89
# red_bit_binary= 01011001
# red_bit_decimal_set_lsb= 88
# green_bit_decimal= 89
# green_bit_binary= 01011001
# green_bit_decimal_set_lsb= 88
# blue_bit_decimal= 89
# blue_bit_binary= 01011001
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [71,150]
# red_bit_decimal= 201
# red_bit_binary= 11001001
# red_bit_decimal_set_lsb= 200
# green_bit_decimal= 201
# green_bit_binary= 11001001
# green_bit_decimal_set_lsb= 200
# blue_bit_decimal= 199
# blue_bit_binary= 11000111
# blue_bit_decimal_set_lsb= 196
# [+] Pixel : [72,150]
# red_bit_decimal= 246
# red_bit_binary= 11110110
# red_bit_decimal_set_lsb= 244
# green_bit_decimal= 246
# green_bit_binary= 11110110
# green_bit_decimal_set_lsb= 244
# blue_bit_decimal= 244
# blue_bit_binary= 11110100
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [73,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 251
# green_bit_binary= 11111011
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 249
# blue_bit_binary= 11111001
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [74,150]
# red_bit_decimal= 250
# red_bit_binary= 11111010
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 249
# green_bit_binary= 11111001
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 247
# blue_bit_binary= 11110111
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [75,150]
# red_bit_decimal= 243
# red_bit_binary= 11110011
# red_bit_decimal_set_lsb= 240
# green_bit_decimal= 239
# green_bit_binary= 11101111
# green_bit_decimal_set_lsb= 236
# blue_bit_decimal= 236
# blue_bit_binary= 11101100
# blue_bit_decimal_set_lsb= 236
# [+] Pixel : [76,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 250
# green_bit_binary= 11111010
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 247
# blue_bit_binary= 11110111
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [77,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 251
# green_bit_binary= 11111011
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [78,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 249
# green_bit_binary= 11111001
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 252
# blue_bit_binary= 11111100
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [79,150]
# red_bit_decimal= 224
# red_bit_binary= 11100000
# red_bit_decimal_set_lsb= 224
# green_bit_decimal= 223
# green_bit_binary= 11011111
# green_bit_decimal_set_lsb= 220
# blue_bit_decimal= 229
# blue_bit_binary= 11100101
# blue_bit_decimal_set_lsb= 228
# [+] Pixel : [80,150]
# red_bit_decimal= 196
# red_bit_binary= 11000100
# red_bit_decimal_set_lsb= 196
# green_bit_decimal= 186
# green_bit_binary= 10111010
# green_bit_decimal_set_lsb= 184
# blue_bit_decimal= 187
# blue_bit_binary= 10111011
# blue_bit_decimal_set_lsb= 184
# [+] Pixel : [81,150]
# red_bit_decimal= 136
# red_bit_binary= 10001000
# red_bit_decimal_set_lsb= 136
# green_bit_decimal= 130
# green_bit_binary= 10000010
# green_bit_decimal_set_lsb= 128
# blue_bit_decimal= 132
# blue_bit_binary= 10000100
# blue_bit_decimal_set_lsb= 132
# [+] Pixel : [82,150]
# red_bit_decimal= 91
# red_bit_binary= 01011011
# red_bit_decimal_set_lsb= 88
# green_bit_decimal= 89
# green_bit_binary= 01011001
# green_bit_decimal_set_lsb= 88
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [83,150]
# red_bit_decimal= 60
# red_bit_binary= 00111100
# red_bit_decimal_set_lsb= 60
# green_bit_decimal= 63
# green_bit_binary= 00111111
# green_bit_decimal_set_lsb= 60
# blue_bit_decimal= 70
# blue_bit_binary= 01000110
# blue_bit_decimal_set_lsb= 68
# [+] Pixel : [84,150]
# red_bit_decimal= 35
# red_bit_binary= 00100011
# red_bit_decimal_set_lsb= 32
# green_bit_decimal= 42
# green_bit_binary= 00101010
# green_bit_decimal_set_lsb= 40
# blue_bit_decimal= 52
# blue_bit_binary= 00110100
# blue_bit_decimal_set_lsb= 52
# [+] Pixel : [85,150]
# red_bit_decimal= 21
# red_bit_binary= 00010101
# red_bit_decimal_set_lsb= 20
# green_bit_decimal= 31
# green_bit_binary= 00011111
# green_bit_decimal_set_lsb= 28
# blue_bit_decimal= 41
# blue_bit_binary= 00101001
# blue_bit_decimal_set_lsb= 40
# [+] Pixel : [86,150]
# red_bit_decimal= 15
# red_bit_binary= 00001111
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 25
# green_bit_binary= 00011001
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 37
# blue_bit_binary= 00100101
# blue_bit_decimal_set_lsb= 36
# [+] Pixel : [87,150]
# red_bit_decimal= 15
# red_bit_binary= 00001111
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 27
# green_bit_binary= 00011011
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 41
# blue_bit_binary= 00101001
# blue_bit_decimal_set_lsb= 40
# [+] Pixel : [88,150]
# red_bit_decimal= 14
# red_bit_binary= 00001110
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 26
# green_bit_binary= 00011010
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 38
# blue_bit_binary= 00100110
# blue_bit_decimal_set_lsb= 36
# [+] Pixel : [89,150]
# red_bit_decimal= 14
# red_bit_binary= 00001110
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 28
# green_bit_binary= 00011100
# green_bit_decimal_set_lsb= 28
# blue_bit_decimal= 39
# blue_bit_binary= 00100111
# blue_bit_decimal_set_lsb= 36
# [+] Pixel : [90,150]
# red_bit_decimal= 12
# red_bit_binary= 00001100
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 26
# green_bit_binary= 00011010
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 35
# blue_bit_binary= 00100011
# blue_bit_decimal_set_lsb= 32
# [+] Pixel : [91,150]
# red_bit_decimal= 12
# red_bit_binary= 00001100
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 26
# green_bit_binary= 00011010
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 35
# blue_bit_binary= 00100011
# blue_bit_decimal_set_lsb= 32
# [+] Pixel : [92,150]
# red_bit_decimal= 13
# red_bit_binary= 00001101
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 26
# green_bit_binary= 00011010
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 34
# blue_bit_binary= 00100010
# blue_bit_decimal_set_lsb= 32
# [+] Pixel : [93,150]
# red_bit_decimal= 16
# red_bit_binary= 00010000
# red_bit_decimal_set_lsb= 16
# green_bit_decimal= 25
# green_bit_binary= 00011001
# green_bit_decimal_set_lsb= 24
# blue_bit_decimal= 34
# blue_bit_binary= 00100010
# blue_bit_decimal_set_lsb= 32
# [+] Pixel : [94,150]
# red_bit_decimal= 32
# red_bit_binary= 00100000
# red_bit_decimal_set_lsb= 32
# green_bit_decimal= 36
# green_bit_binary= 00100100
# green_bit_decimal_set_lsb= 36
# blue_bit_decimal= 47
# blue_bit_binary= 00101111
# blue_bit_decimal_set_lsb= 44
# [+] Pixel : [95,150]
# red_bit_decimal= 53
# red_bit_binary= 00110101
# red_bit_decimal_set_lsb= 52
# green_bit_decimal= 55
# green_bit_binary= 00110111
# green_bit_decimal_set_lsb= 52
# blue_bit_decimal= 67
# blue_bit_binary= 01000011
# blue_bit_decimal_set_lsb= 64
# [+] Pixel : [96,150]
# red_bit_decimal= 73
# red_bit_binary= 01001001
# red_bit_decimal_set_lsb= 72
# green_bit_decimal= 84
# green_bit_binary= 01010100
# green_bit_decimal_set_lsb= 84
# blue_bit_decimal= 80
# blue_bit_binary= 01010000
# blue_bit_decimal_set_lsb= 80
# [+] Pixel : [97,150]
# red_bit_decimal= 110
# red_bit_binary= 01101110
# red_bit_decimal_set_lsb= 108
# green_bit_decimal= 119
# green_bit_binary= 01110111
# green_bit_decimal_set_lsb= 116
# blue_bit_decimal= 114
# blue_bit_binary= 01110010
# blue_bit_decimal_set_lsb= 112
# [+] Pixel : [98,150]
# red_bit_decimal= 150
# red_bit_binary= 10010110
# red_bit_decimal_set_lsb= 148
# green_bit_decimal= 156
# green_bit_binary= 10011100
# green_bit_decimal_set_lsb= 156
# blue_bit_decimal= 152
# blue_bit_binary= 10011000
# blue_bit_decimal_set_lsb= 152
# [+] Pixel : [99,150]
# red_bit_decimal= 183
# red_bit_binary= 10110111
# red_bit_decimal_set_lsb= 180
# green_bit_decimal= 188
# green_bit_binary= 10111100
# green_bit_decimal_set_lsb= 188
# blue_bit_decimal= 182
# blue_bit_binary= 10110110
# blue_bit_decimal_set_lsb= 180
# [+] Pixel : [100,150]
# red_bit_decimal= 220
# red_bit_binary= 11011100
# red_bit_decimal_set_lsb= 220
# green_bit_decimal= 221
# green_bit_binary= 11011101
# green_bit_decimal_set_lsb= 220
# blue_bit_decimal= 216
# blue_bit_binary= 11011000
# blue_bit_decimal_set_lsb= 216
# [+] Pixel : [101,150]
# red_bit_decimal= 248
# red_bit_binary= 11111000
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 247
# green_bit_binary= 11110111
# green_bit_decimal_set_lsb= 244
# blue_bit_decimal= 242
# blue_bit_binary= 11110010
# blue_bit_decimal_set_lsb= 240
# [+] Pixel : [102,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [103,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 252
# green_bit_binary= 11111100
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 247
# blue_bit_binary= 11110111
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [104,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 251
# green_bit_binary= 11111011
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 246
# blue_bit_binary= 11110110
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [105,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 251
# blue_bit_binary= 11111011
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [106,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [107,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [108,150]
# red_bit_decimal= 248
# red_bit_binary= 11111000
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 250
# green_bit_binary= 11111010
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 249
# blue_bit_binary= 11111001
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [109,150]
# red_bit_decimal= 241
# red_bit_binary= 11110001
# red_bit_decimal_set_lsb= 240
# green_bit_decimal= 245
# green_bit_binary= 11110101
# green_bit_decimal_set_lsb= 244
# blue_bit_decimal= 246
# blue_bit_binary= 11110110
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [110,150]
# red_bit_decimal= 250
# red_bit_binary= 11111010
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [111,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [112,150]
# red_bit_decimal= 252
# red_bit_binary= 11111100
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 252
# green_bit_binary= 11111100
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [113,150]
# red_bit_decimal= 252
# red_bit_binary= 11111100
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 252
# green_bit_binary= 11111100
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [114,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 251
# green_bit_binary= 11111011
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 249
# blue_bit_binary= 11111001
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [115,150]
# red_bit_decimal= 252
# red_bit_binary= 11111100
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 252
# green_bit_binary= 11111100
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 250
# blue_bit_binary= 11111010
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [116,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 253
# green_bit_binary= 11111101
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 251
# blue_bit_binary= 11111011
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [117,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 252
# blue_bit_binary= 11111100
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [118,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [119,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 254
# blue_bit_binary= 11111110
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [120,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [121,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [122,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [123,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [124,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [125,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [126,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [127,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [128,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [129,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [130,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [131,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [132,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [133,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 254
# blue_bit_binary= 11111110
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [134,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 254
# blue_bit_binary= 11111110
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [135,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 254
# blue_bit_binary= 11111110
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [136,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [137,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [138,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [139,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [140,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [141,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [142,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [143,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [144,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [145,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 253
# green_bit_binary= 11111101
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [146,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 251
# green_bit_binary= 11111011
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 251
# blue_bit_binary= 11111011
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [147,150]
# red_bit_decimal= 215
# red_bit_binary= 11010111
# red_bit_decimal_set_lsb= 212
# green_bit_decimal= 215
# green_bit_binary= 11010111
# green_bit_decimal_set_lsb= 212
# blue_bit_decimal= 213
# blue_bit_binary= 11010101
# blue_bit_decimal_set_lsb= 212
# [+] Pixel : [148,150]
# red_bit_decimal= 97
# red_bit_binary= 01100001
# red_bit_decimal_set_lsb= 96
# green_bit_decimal= 97
# green_bit_binary= 01100001
# green_bit_decimal_set_lsb= 96
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [149,150]
# red_bit_decimal= 8
# red_bit_binary= 00001000
# red_bit_decimal_set_lsb= 8
# green_bit_decimal= 8
# green_bit_binary= 00001000
# green_bit_decimal_set_lsb= 8
# blue_bit_decimal= 8
# blue_bit_binary= 00001000
# blue_bit_decimal_set_lsb= 8
# [+] Pixel : [150,150]
# red_bit_decimal= 12
# red_bit_binary= 00001100
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 10
# green_bit_binary= 00001010
# green_bit_decimal_set_lsb= 8
# blue_bit_decimal= 11
# blue_bit_binary= 00001011
# blue_bit_decimal_set_lsb= 8
# [+] Pixel : [151,150]
# red_bit_decimal= 13
# red_bit_binary= 00001101
# red_bit_decimal_set_lsb= 12
# green_bit_decimal= 7
# green_bit_binary= 00000111
# green_bit_decimal_set_lsb= 4
# blue_bit_decimal= 9
# blue_bit_binary= 00001001
# blue_bit_decimal_set_lsb= 8
# [+] Pixel : [152,150]
# red_bit_decimal= 44
# red_bit_binary= 00101100
# red_bit_decimal_set_lsb= 44
# green_bit_decimal= 38
# green_bit_binary= 00100110
# green_bit_decimal_set_lsb= 36
# blue_bit_decimal= 42
# blue_bit_binary= 00101010
# blue_bit_decimal_set_lsb= 40
# [+] Pixel : [153,150]
# red_bit_decimal= 55
# red_bit_binary= 00110111
# red_bit_decimal_set_lsb= 52
# green_bit_decimal= 52
# green_bit_binary= 00110100
# green_bit_decimal_set_lsb= 52
# blue_bit_decimal= 59
# blue_bit_binary= 00111011
# blue_bit_decimal_set_lsb= 56
# [+] Pixel : [154,150]
# red_bit_decimal= 2
# red_bit_binary= 00000010
# red_bit_decimal_set_lsb= 0
# green_bit_decimal= 12
# green_bit_binary= 00001100
# green_bit_decimal_set_lsb= 12
# blue_bit_decimal= 21
# blue_bit_binary= 00010101
# blue_bit_decimal_set_lsb= 20
# [+] Pixel : [155,150]
# red_bit_decimal= 21
# red_bit_binary= 00010101
# red_bit_decimal_set_lsb= 20
# green_bit_decimal= 53
# green_bit_binary= 00110101
# green_bit_decimal_set_lsb= 52
# blue_bit_decimal= 68
# blue_bit_binary= 01000100
# blue_bit_decimal_set_lsb= 68
# [+] Pixel : [156,150]
# red_bit_decimal= 78
# red_bit_binary= 01001110
# red_bit_decimal_set_lsb= 76
# green_bit_decimal= 136
# green_bit_binary= 10001000
# green_bit_decimal_set_lsb= 136
# blue_bit_decimal= 158
# blue_bit_binary= 10011110
# blue_bit_decimal_set_lsb= 156
# [+] Pixel : [157,150]
# red_bit_decimal= 96
# red_bit_binary= 01100000
# red_bit_decimal_set_lsb= 96
# green_bit_decimal= 181
# green_bit_binary= 10110101
# green_bit_decimal_set_lsb= 180
# blue_bit_decimal= 212
# blue_bit_binary= 11010100
# blue_bit_decimal_set_lsb= 212
# [+] Pixel : [158,150]
# red_bit_decimal= 87
# red_bit_binary= 01010111
# red_bit_decimal_set_lsb= 84
# green_bit_decimal= 193
# green_bit_binary= 11000001
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 233
# blue_bit_binary= 11101001
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [159,150]
# red_bit_decimal= 80
# red_bit_binary= 01010000
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 198
# green_bit_binary= 11000110
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 244
# blue_bit_binary= 11110100
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [160,150]
# red_bit_decimal= 68
# red_bit_binary= 01000100
# red_bit_decimal_set_lsb= 68
# green_bit_decimal= 197
# green_bit_binary= 11000101
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 237
# blue_bit_binary= 11101101
# blue_bit_decimal_set_lsb= 236
# [+] Pixel : [161,150]
# red_bit_decimal= 76
# red_bit_binary= 01001100
# red_bit_decimal_set_lsb= 76
# green_bit_decimal= 203
# green_bit_binary= 11001011
# green_bit_decimal_set_lsb= 200
# blue_bit_decimal= 244
# blue_bit_binary= 11110100
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [162,150]
# red_bit_decimal= 70
# red_bit_binary= 01000110
# red_bit_decimal_set_lsb= 68
# green_bit_decimal= 196
# green_bit_binary= 11000100
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 237
# blue_bit_binary= 11101101
# blue_bit_decimal_set_lsb= 236
# [+] Pixel : [163,150]
# red_bit_decimal= 80
# red_bit_binary= 01010000
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 197
# green_bit_binary= 11000101
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 240
# blue_bit_binary= 11110000
# blue_bit_decimal_set_lsb= 240
# [+] Pixel : [164,150]
# red_bit_decimal= 86
# red_bit_binary= 01010110
# red_bit_decimal_set_lsb= 84
# green_bit_decimal= 195
# green_bit_binary= 11000011
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 234
# blue_bit_binary= 11101010
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [165,150]
# red_bit_decimal= 100
# red_bit_binary= 01100100
# red_bit_decimal_set_lsb= 100
# green_bit_decimal= 198
# green_bit_binary= 11000110
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 233
# blue_bit_binary= 11101001
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [166,150]
# red_bit_decimal= 90
# red_bit_binary= 01011010
# red_bit_decimal_set_lsb= 88
# green_bit_decimal= 175
# green_bit_binary= 10101111
# green_bit_decimal_set_lsb= 172
# blue_bit_decimal= 206
# blue_bit_binary= 11001110
# blue_bit_decimal_set_lsb= 204
# [+] Pixel : [167,150]
# red_bit_decimal= 86
# red_bit_binary= 01010110
# red_bit_decimal_set_lsb= 84
# green_bit_decimal= 157
# green_bit_binary= 10011101
# green_bit_decimal_set_lsb= 156
# blue_bit_decimal= 185
# blue_bit_binary= 10111001
# blue_bit_decimal_set_lsb= 184
# [+] Pixel : [168,150]
# red_bit_decimal= 65
# red_bit_binary= 01000001
# red_bit_decimal_set_lsb= 64
# green_bit_decimal= 125
# green_bit_binary= 01111101
# green_bit_decimal_set_lsb= 124
# blue_bit_decimal= 153
# blue_bit_binary= 10011001
# blue_bit_decimal_set_lsb= 152
# [+] Pixel : [169,150]
# red_bit_decimal= 48
# red_bit_binary= 00110000
# red_bit_decimal_set_lsb= 48
# green_bit_decimal= 98
# green_bit_binary= 01100010
# green_bit_decimal_set_lsb= 96
# blue_bit_decimal= 123
# blue_bit_binary= 01111011
# blue_bit_decimal_set_lsb= 120
# [+] Pixel : [170,150]
# red_bit_decimal= 32
# red_bit_binary= 00100000
# red_bit_decimal_set_lsb= 32
# green_bit_decimal= 77
# green_bit_binary= 01001101
# green_bit_decimal_set_lsb= 76
# blue_bit_decimal= 98
# blue_bit_binary= 01100010
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [171,150]
# red_bit_decimal= 29
# red_bit_binary= 00011101
# red_bit_decimal_set_lsb= 28
# green_bit_decimal= 72
# green_bit_binary= 01001000
# green_bit_decimal_set_lsb= 72
# blue_bit_decimal= 89
# blue_bit_binary= 01011001
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [172,150]
# red_bit_decimal= 26
# red_bit_binary= 00011010
# red_bit_decimal_set_lsb= 24
# green_bit_decimal= 72
# green_bit_binary= 01001000
# green_bit_decimal_set_lsb= 72
# blue_bit_decimal= 87
# blue_bit_binary= 01010111
# blue_bit_decimal_set_lsb= 84
# [+] Pixel : [173,150]
# red_bit_decimal= 31
# red_bit_binary= 00011111
# red_bit_decimal_set_lsb= 28
# green_bit_decimal= 79
# green_bit_binary= 01001111
# green_bit_decimal_set_lsb= 76
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [174,150]
# red_bit_decimal= 42
# red_bit_binary= 00101010
# red_bit_decimal_set_lsb= 40
# green_bit_decimal= 93
# green_bit_binary= 01011101
# green_bit_decimal_set_lsb= 92
# blue_bit_decimal= 110
# blue_bit_binary= 01101110
# blue_bit_decimal_set_lsb= 108
# [+] Pixel : [175,150]
# red_bit_decimal= 54
# red_bit_binary= 00110110
# red_bit_decimal_set_lsb= 52
# green_bit_decimal= 107
# green_bit_binary= 01101011
# green_bit_decimal_set_lsb= 104
# blue_bit_decimal= 125
# blue_bit_binary= 01111101
# blue_bit_decimal_set_lsb= 124
# [+] Pixel : [176,150]
# red_bit_decimal= 59
# red_bit_binary= 00111011
# red_bit_decimal_set_lsb= 56
# green_bit_decimal= 135
# green_bit_binary= 10000111
# green_bit_decimal_set_lsb= 132
# blue_bit_decimal= 161
# blue_bit_binary= 10100001
# blue_bit_decimal_set_lsb= 160
# [+] Pixel : [177,150]
# red_bit_decimal= 81
# red_bit_binary= 01010001
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 162
# green_bit_binary= 10100010
# green_bit_decimal_set_lsb= 160
# blue_bit_decimal= 189
# blue_bit_binary= 10111101
# blue_bit_decimal_set_lsb= 188
# [+] Pixel : [178,150]
# red_bit_decimal= 94
# red_bit_binary= 01011110
# red_bit_decimal_set_lsb= 92
# green_bit_decimal= 188
# green_bit_binary= 10111100
# green_bit_decimal_set_lsb= 188
# blue_bit_decimal= 216
# blue_bit_binary= 11011000
# blue_bit_decimal_set_lsb= 216
# [+] Pixel : [179,150]
# red_bit_decimal= 91
# red_bit_binary= 01011011
# red_bit_decimal_set_lsb= 88
# green_bit_decimal= 198
# green_bit_binary= 11000110
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 230
# blue_bit_binary= 11100110
# blue_bit_decimal_set_lsb= 228
# [+] Pixel : [180,150]
# red_bit_decimal= 81
# red_bit_binary= 01010001
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 198
# green_bit_binary= 11000110
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 233
# blue_bit_binary= 11101001
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [181,150]
# red_bit_decimal= 69
# red_bit_binary= 01000101
# red_bit_decimal_set_lsb= 68
# green_bit_decimal= 193
# green_bit_binary= 11000001
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 231
# blue_bit_binary= 11100111
# blue_bit_decimal_set_lsb= 228
# [+] Pixel : [182,150]
# red_bit_decimal= 68
# red_bit_binary= 01000100
# red_bit_decimal_set_lsb= 68
# green_bit_decimal= 194
# green_bit_binary= 11000010
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 234
# blue_bit_binary= 11101010
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [183,150]
# red_bit_decimal= 82
# red_bit_binary= 01010010
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 205
# green_bit_binary= 11001101
# green_bit_decimal_set_lsb= 204
# blue_bit_decimal= 247
# blue_bit_binary= 11110111
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [184,150]
# red_bit_decimal= 78
# red_bit_binary= 01001110
# red_bit_decimal_set_lsb= 76
# green_bit_decimal= 199
# green_bit_binary= 11000111
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 242
# blue_bit_binary= 11110010
# blue_bit_decimal_set_lsb= 240
# [+] Pixel : [185,150]
# red_bit_decimal= 80
# red_bit_binary= 01010000
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 197
# green_bit_binary= 11000101
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 241
# blue_bit_binary= 11110001
# blue_bit_decimal_set_lsb= 240
# [+] Pixel : [186,150]
# red_bit_decimal= 78
# red_bit_binary= 01001110
# red_bit_decimal_set_lsb= 76
# green_bit_decimal= 193
# green_bit_binary= 11000001
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 237
# blue_bit_binary= 11101101
# blue_bit_decimal_set_lsb= 236
# [+] Pixel : [187,150]
# red_bit_decimal= 82
# red_bit_binary= 01010010
# red_bit_decimal_set_lsb= 80
# green_bit_decimal= 195
# green_bit_binary= 11000011
# green_bit_decimal_set_lsb= 192
# blue_bit_decimal= 235
# blue_bit_binary= 11101011
# blue_bit_decimal_set_lsb= 232
# [+] Pixel : [188,150]
# red_bit_decimal= 87
# red_bit_binary= 01010111
# red_bit_decimal_set_lsb= 84
# green_bit_decimal= 199
# green_bit_binary= 11000111
# green_bit_decimal_set_lsb= 196
# blue_bit_decimal= 237
# blue_bit_binary= 11101101
# blue_bit_decimal_set_lsb= 236
# ...
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 228
# green_bit_binary= 11100100
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 99
# blue_bit_binary= 01100011
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [334,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [335,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 232
# green_bit_binary= 11101000
# green_bit_decimal_set_lsb= 232
# blue_bit_decimal= 90
# blue_bit_binary= 01011010
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [336,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [337,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [338,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [339,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [340,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 96
# blue_bit_binary= 01100000
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [341,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 96
# blue_bit_binary= 01100000
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [342,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [343,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [344,150]
# red_bit_decimal= 254
# red_bit_binary= 11111110
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 227
# green_bit_binary= 11100011
# green_bit_decimal_set_lsb= 224
# blue_bit_decimal= 94
# blue_bit_binary= 01011110
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [345,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 97
# blue_bit_binary= 01100001
# blue_bit_decimal_set_lsb= 96
# [+] Pixel : [346,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 229
# green_bit_binary= 11100101
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 93
# blue_bit_binary= 01011101
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [347,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 234
# green_bit_binary= 11101010
# green_bit_decimal_set_lsb= 232
# blue_bit_decimal= 95
# blue_bit_binary= 01011111
# blue_bit_decimal_set_lsb= 92
# [+] Pixel : [348,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 228
# green_bit_binary= 11100100
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 89
# blue_bit_binary= 01011001
# blue_bit_decimal_set_lsb= 88
# [+] Pixel : [349,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 230
# green_bit_binary= 11100110
# green_bit_decimal_set_lsb= 228
# blue_bit_decimal= 101
# blue_bit_binary= 01100101
# blue_bit_decimal_set_lsb= 100
# [+] Pixel : [350,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 239
# green_bit_binary= 11101111
# green_bit_decimal_set_lsb= 236
# blue_bit_decimal= 123
# blue_bit_binary= 01111011
# blue_bit_decimal_set_lsb= 120
# [+] Pixel : [351,150]
# red_bit_decimal= 237
# red_bit_binary= 11101101
# red_bit_decimal_set_lsb= 236
# green_bit_decimal= 216
# green_bit_binary= 11011000
# green_bit_decimal_set_lsb= 216
# blue_bit_decimal= 109
# blue_bit_binary= 01101101
# blue_bit_decimal_set_lsb= 108
# [+] Pixel : [352,150]
# red_bit_decimal= 131
# red_bit_binary= 10000011
# red_bit_decimal_set_lsb= 128
# green_bit_decimal= 119
# green_bit_binary= 01110111
# green_bit_decimal_set_lsb= 116
# blue_bit_decimal= 59
# blue_bit_binary= 00111011
# blue_bit_decimal_set_lsb= 56
# [+] Pixel : [353,150]
# red_bit_decimal= 44
# red_bit_binary= 00101100
# red_bit_decimal_set_lsb= 44
# green_bit_decimal= 36
# green_bit_binary= 00100100
# green_bit_decimal_set_lsb= 36
# blue_bit_decimal= 0
# blue_bit_binary= 00000000
# blue_bit_decimal_set_lsb= 0
# [+] Pixel : [354,150]
# red_bit_decimal= 7
# red_bit_binary= 00000111
# red_bit_decimal_set_lsb= 4
# green_bit_decimal= 2
# green_bit_binary= 00000010
# green_bit_decimal_set_lsb= 0
# blue_bit_decimal= 0
# blue_bit_binary= 00000000
# blue_bit_decimal_set_lsb= 0
# [+] Pixel : [355,150]
# red_bit_decimal= 11
# red_bit_binary= 00001011
# red_bit_decimal_set_lsb= 8
# green_bit_decimal= 13
# green_bit_binary= 00001101
# green_bit_decimal_set_lsb= 12
# blue_bit_decimal= 12
# blue_bit_binary= 00001100
# blue_bit_decimal_set_lsb= 12
# [+] Pixel : [356,150]
# red_bit_decimal= 9
# red_bit_binary= 00001001
# red_bit_decimal_set_lsb= 8
# green_bit_decimal= 16
# green_bit_binary= 00010000
# green_bit_decimal_set_lsb= 16
# blue_bit_decimal= 26
# blue_bit_binary= 00011010
# blue_bit_decimal_set_lsb= 24
# [+] Pixel : [357,150]
# red_bit_decimal= 84
# red_bit_binary= 01010100
# red_bit_decimal_set_lsb= 84
# green_bit_decimal= 94
# green_bit_binary= 01011110
# green_bit_decimal_set_lsb= 92
# blue_bit_decimal= 104
# blue_bit_binary= 01101000
# blue_bit_decimal_set_lsb= 104
# [+] Pixel : [358,150]
# red_bit_decimal= 195
# red_bit_binary= 11000011
# red_bit_decimal_set_lsb= 192
# green_bit_decimal= 206
# green_bit_binary= 11001110
# green_bit_decimal_set_lsb= 204
# blue_bit_decimal= 210
# blue_bit_binary= 11010010
# blue_bit_decimal_set_lsb= 208
# [+] Pixel : [359,150]
# red_bit_decimal= 249
# red_bit_binary= 11111001
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [360,150]
# red_bit_decimal= 247
# red_bit_binary= 11110111
# red_bit_decimal_set_lsb= 244
# green_bit_decimal= 252
# green_bit_binary= 11111100
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 246
# blue_bit_binary= 11110110
# blue_bit_decimal_set_lsb= 244
# [+] Pixel : [361,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 251
# blue_bit_binary= 11111011
# blue_bit_decimal_set_lsb= 248
# [+] Pixel : [362,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 253
# blue_bit_binary= 11111101
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [363,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 254
# green_bit_binary= 11111110
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [364,150]
# red_bit_decimal= 251
# red_bit_binary= 11111011
# red_bit_decimal_set_lsb= 248
# green_bit_decimal= 249
# green_bit_binary= 11111001
# green_bit_decimal_set_lsb= 248
# blue_bit_decimal= 252
# blue_bit_binary= 11111100
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [365,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [366,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [367,150]
# red_bit_decimal= 253
# red_bit_binary= 11111101
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 254
# blue_bit_binary= 11111110
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [368,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [369,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [370,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [371,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [372,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [373,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [374,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [375,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [376,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [377,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [378,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [379,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [380,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [381,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [382,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [383,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [384,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [385,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [386,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [387,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [388,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [389,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# [+] Pixel : [390,150]
# red_bit_decimal= 255
# red_bit_binary= 11111111
# red_bit_decimal_set_lsb= 252
# green_bit_decimal= 255
# green_bit_binary= 11111111
# green_bit_decimal_set_lsb= 252
# blue_bit_decimal= 255
# blue_bit_binary= 11111111
# blue_bit_decimal_set_lsb= 252
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-809bd7783fac> in <module>
# ----> 1 GenWatermark()
#
# <ipython-input-4-3e051c7e5da5> in GenWatermark()
#      64
#      65     im.close()
# ---> 66     im.save('lsb_spongebob.png')
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    1958
#    1959         # may mutate self!
# -> 1960         self.load()
#    1961
#    1962         save_all = params.pop('save_all', False)
#
# /opt/conda/lib/python3.7/site-packages/PIL/ImageFile.py in load(self)
#     137         "Load image data based on tile list"
#     138
# --> 139         pixel = Image.Image.load(self)
#     140
#     141         if self.tile is None:
#
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py in load(self)
#     857                 if self.pyaccess:
#     858                     return self.pyaccess
# --> 859             return self.im.pixel_access(self.readonly)
#     860
#     861     def verify(self):
#
# /opt/conda/lib/python3.7/site-packages/PIL/_util.py in __getattr__(self, elt)
#      28
#      29     def __getattr__(self, elt):
# ---> 30         raise self.ex
#
# ValueError: Operation on closed image

# %% [markdown]
# #### runs Embed to embed both kinds of watermark into image, take grayscale images for instance, where the number of gray levels is 256
