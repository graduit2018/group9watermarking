# %%
#CSS Cloud Service Server
#TPA Third Party Auditor

# %% [markdown]
# # Setup phase

# %% [markdown]
# #### client generates its public and private parameters by invoking GenKey

# %%
import string
import random
from math import sqrt 

# Returns True if n is prime  
def isPrime( n):  
  
    # Corner cases  
    if (n <= 1): 
        return False
    if (n <= 3): 
        return True
  
    # This is checked so that we can skip  
    # middle five numbers in below loop  
    if (n % 2 == 0 or n % 3 == 0): 
        return False
    i = 5
    while(i * i <= n): 
        if (n % i == 0 or n % (i + 2) == 0) : 
            return False
        i = i + 6
  
    return True
  
""" Iterative Function to calculate (x^n)%p 
    in O(logy) */"""
def power( x, y, p):  
  
    res = 1 # Initialize result  
  
    x = x % p # Update x if it is more  
              # than or equal to p  
  
    while (y > 0):  
  
        # If y is odd, multiply x with result  
        if (y & 1): 
            res = (res * x) % p  
  
        # y must be even now  
        y = y >> 1 # y = y/2  
        x = (x * x) % p  
  
    return res  
  
# Utility function to store prime 
# factors of a number  
def findPrimefactors(s, n) : 
  
    # Pr the number of 2s that divide n  
    while (n % 2 == 0) : 
        s.add(2)  
        n = n // 2
  
    # n must be odd at this po. So we can   
    # skip one element (Note i = i +2)  
    for i in range(3, int(sqrt(n)), 2): 
          
        # While i divides n, pr i and divide n  
        while (n % i == 0) : 
  
            s.add(i)  
            n = n // i  
          
    # This condition is to handle the case  
    # when n is a prime number greater than 2  
    if (n > 2) : 
        s.add(n)  

# Function to find smallest primitive
# root of n  
def findPrimitive( n) : 
    s = set()  
  
    # Check if n is prime or not  
    if (isPrime(n) == False):  
        return -1
  
    # Find value of Euler Totient function  
    # of n. Since n is a prime number, the  
    # value of Euler Totient function is n-1  
    # as there are n-1 relatively prime numbers. 
    phi = n - 1
  
    # Find prime factors of phi and store in a set  
    findPrimefactors(s, phi)  
  
    # Check for every number from 2 to phi  
    for r in range(2, phi + 1):  
  
        # Iterate through all prime factors of phi.  
        # and check if we found a power with value 1  
        flag = False
        for it in s:  
  
            # Check if r^((phi)/primefactors) 
            # mod n is 1 or not  
            if (power(r, phi // it, n) == 1):  
  
                flag = True
                break
              
        # If there was no power with value 1.  
        if (flag == False): 
            return r  
  
    # If no primitive root found  
    return -1

def key_generator(size=6, chars=string.ascii_uppercase + string.digits):
    return ''.join(random.choice(chars) for _ in range(size))

def GenKey(k):
    q = 1000
    primes = [i for i in range(2,q) if isPrime(i)]
    n = random.choice(primes)
    g = findPrimitive(n)
    key_prp = key_generator()
    key_sym = key_generator()
    pk = random.choice([n, g])
    sk = random.choice([key_prp, key_sym])
    return pk, sk

# %%
pk, sk = GenKey(4)
print(pk)
print(sk)
# Out:
# 2
# FD45P4

# %% [markdown]
# #### running Gen Watermark produces the verification watermark and the recovery watermark

# %%
import bitarray
import base64

# message = pk
# encoded_message = base64.b64encode(message)
# #Converts the message into an array of bits
# ba = bitarray.bitarray()
# ba.frombytes(encoded_message.encode('utf-8'))
# bit_array = [int(i) for i in ba]

from PIL import Image

def GenWatermark():
    im = Image.open("lsb_spongebob.png")
    width, height = im.size
    print('width = %d'%width)
    pixels = im.load()
    print(pixels)

    i = 0
    # each pixel of the row 150th
    for x in range(0,width):
        r,g,b = pixels[x,150]
        print("[+] Pixel : [%d,%d]"%(x,150))
#         print("[+] \tBefore : (%d,%d,%d)"%(r,g,b))        
        
        #Red pixel
        print('red_bit_decimal= %d'%r)
        r_bit = bin(r)
        print('red_bit_binary= %s'%r_bit)
        r_lsb_bit = r_bit[-2:]
        print('2 red lsb = %s'%r_lsb_bit)

# %%
GenWatermark()
# Out:
# width = 391
# <PixelAccess object at 0x7f0559234550>
# [+] Pixel : [0,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [1,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [2,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [3,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [4,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [5,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [6,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [7,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [8,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [9,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [10,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [11,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [12,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [13,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [14,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [15,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [16,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [17,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [18,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [19,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [20,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [21,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [22,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [23,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [24,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [25,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [26,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [27,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [28,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [29,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [30,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [31,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [32,150]
# red_bit_decimal= 129
# red_bit_binary= 0b10000001
# 2 red lsb = 01
# [+] Pixel : [33,150]
# red_bit_decimal= 124
# red_bit_binary= 0b1111100
# 2 red lsb = 00
# [+] Pixel : [34,150]
# red_bit_decimal= 124
# red_bit_binary= 0b1111100
# 2 red lsb = 00
# [+] Pixel : [35,150]
# red_bit_decimal= 141
# red_bit_binary= 0b10001101
# 2 red lsb = 01
# [+] Pixel : [36,150]
# red_bit_decimal= 151
# red_bit_binary= 0b10010111
# 2 red lsb = 11
# [+] Pixel : [37,150]
# red_bit_decimal= 212
# red_bit_binary= 0b11010100
# 2 red lsb = 00
# [+] Pixel : [38,150]
# red_bit_decimal= 244
# red_bit_binary= 0b11110100
# 2 red lsb = 00
# [+] Pixel : [39,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [40,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [41,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [42,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [43,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [44,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [45,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [46,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [47,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [48,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [49,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [50,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [51,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [52,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [53,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [54,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [55,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [56,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [57,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [58,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [59,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [60,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [61,150]
# red_bit_decimal= 252
# red_bit_binary= 0b11111100
# 2 red lsb = 00
# [+] Pixel : [62,150]
# red_bit_decimal= 250
# red_bit_binary= 0b11111010
# 2 red lsb = 10
# [+] Pixel : [63,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [64,150]
# red_bit_decimal= 247
# red_bit_binary= 0b11110111
# 2 red lsb = 11
# [+] Pixel : [65,150]
# red_bit_decimal= 234
# red_bit_binary= 0b11101010
# 2 red lsb = 10
# [+] Pixel : [66,150]
# red_bit_decimal= 122
# red_bit_binary= 0b1111010
# 2 red lsb = 10
# [+] Pixel : [67,150]
# red_bit_decimal= 21
# red_bit_binary= 0b10101
# 2 red lsb = 01
# [+] Pixel : [68,150]
# red_bit_decimal= 19
# red_bit_binary= 0b10011
# 2 red lsb = 11
# [+] Pixel : [69,150]
# red_bit_decimal= 5
# red_bit_binary= 0b101
# 2 red lsb = 01
# [+] Pixel : [70,150]
# red_bit_decimal= 89
# red_bit_binary= 0b1011001
# 2 red lsb = 01
# [+] Pixel : [71,150]
# red_bit_decimal= 201
# red_bit_binary= 0b11001001
# 2 red lsb = 01
# [+] Pixel : [72,150]
# red_bit_decimal= 246
# red_bit_binary= 0b11110110
# 2 red lsb = 10
# [+] Pixel : [73,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [74,150]
# red_bit_decimal= 250
# red_bit_binary= 0b11111010
# 2 red lsb = 10
# [+] Pixel : [75,150]
# red_bit_decimal= 243
# red_bit_binary= 0b11110011
# 2 red lsb = 11
# [+] Pixel : [76,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [77,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [78,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [79,150]
# red_bit_decimal= 224
# red_bit_binary= 0b11100000
# 2 red lsb = 00
# [+] Pixel : [80,150]
# red_bit_decimal= 196
# red_bit_binary= 0b11000100
# 2 red lsb = 00
# [+] Pixel : [81,150]
# red_bit_decimal= 136
# red_bit_binary= 0b10001000
# 2 red lsb = 00
# [+] Pixel : [82,150]
# red_bit_decimal= 91
# red_bit_binary= 0b1011011
# 2 red lsb = 11
# [+] Pixel : [83,150]
# red_bit_decimal= 60
# red_bit_binary= 0b111100
# 2 red lsb = 00
# [+] Pixel : [84,150]
# red_bit_decimal= 35
# red_bit_binary= 0b100011
# 2 red lsb = 11
# [+] Pixel : [85,150]
# red_bit_decimal= 21
# red_bit_binary= 0b10101
# 2 red lsb = 01
# [+] Pixel : [86,150]
# red_bit_decimal= 15
# red_bit_binary= 0b1111
# 2 red lsb = 11
# [+] Pixel : [87,150]
# red_bit_decimal= 15
# red_bit_binary= 0b1111
# 2 red lsb = 11
# [+] Pixel : [88,150]
# red_bit_decimal= 14
# red_bit_binary= 0b1110
# 2 red lsb = 10
# [+] Pixel : [89,150]
# red_bit_decimal= 14
# red_bit_binary= 0b1110
# 2 red lsb = 10
# [+] Pixel : [90,150]
# red_bit_decimal= 12
# red_bit_binary= 0b1100
# 2 red lsb = 00
# [+] Pixel : [91,150]
# red_bit_decimal= 12
# red_bit_binary= 0b1100
# 2 red lsb = 00
# [+] Pixel : [92,150]
# red_bit_decimal= 13
# red_bit_binary= 0b1101
# 2 red lsb = 01
# [+] Pixel : [93,150]
# red_bit_decimal= 16
# red_bit_binary= 0b10000
# 2 red lsb = 00
# [+] Pixel : [94,150]
# red_bit_decimal= 32
# red_bit_binary= 0b100000
# 2 red lsb = 00
# [+] Pixel : [95,150]
# red_bit_decimal= 53
# red_bit_binary= 0b110101
# 2 red lsb = 01
# [+] Pixel : [96,150]
# red_bit_decimal= 73
# red_bit_binary= 0b1001001
# 2 red lsb = 01
# [+] Pixel : [97,150]
# red_bit_decimal= 110
# red_bit_binary= 0b1101110
# 2 red lsb = 10
# [+] Pixel : [98,150]
# red_bit_decimal= 150
# red_bit_binary= 0b10010110
# 2 red lsb = 10
# [+] Pixel : [99,150]
# red_bit_decimal= 183
# red_bit_binary= 0b10110111
# 2 red lsb = 11
# [+] Pixel : [100,150]
# red_bit_decimal= 220
# red_bit_binary= 0b11011100
# 2 red lsb = 00
# [+] Pixel : [101,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [102,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [103,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [104,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [105,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [106,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [107,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [108,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [109,150]
# red_bit_decimal= 241
# red_bit_binary= 0b11110001
# 2 red lsb = 01
# [+] Pixel : [110,150]
# red_bit_decimal= 250
# red_bit_binary= 0b11111010
# 2 red lsb = 10
# [+] Pixel : [111,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [112,150]
# red_bit_decimal= 252
# red_bit_binary= 0b11111100
# 2 red lsb = 00
# [+] Pixel : [113,150]
# red_bit_decimal= 252
# red_bit_binary= 0b11111100
# 2 red lsb = 00
# [+] Pixel : [114,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [115,150]
# red_bit_decimal= 252
# red_bit_binary= 0b11111100
# 2 red lsb = 00
# [+] Pixel : [116,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [117,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [118,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [119,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [120,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [121,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [122,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [123,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [124,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [125,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [126,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [127,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [128,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [129,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [130,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [131,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [132,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [133,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [134,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [135,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [136,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [137,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [138,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [139,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [140,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [141,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [142,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [143,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [144,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [145,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [146,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [147,150]
# red_bit_decimal= 215
# red_bit_binary= 0b11010111
# 2 red lsb = 11
# [+] Pixel : [148,150]
# red_bit_decimal= 97
# red_bit_binary= 0b1100001
# 2 red lsb = 01
# [+] Pixel : [149,150]
# red_bit_decimal= 8
# red_bit_binary= 0b1000
# 2 red lsb = 00
# [+] Pixel : [150,150]
# red_bit_decimal= 12
# red_bit_binary= 0b1100
# 2 red lsb = 00
# [+] Pixel : [151,150]
# red_bit_decimal= 13
# red_bit_binary= 0b1101
# 2 red lsb = 01
# [+] Pixel : [152,150]
# red_bit_decimal= 44
# red_bit_binary= 0b101100
# 2 red lsb = 00
# [+] Pixel : [153,150]
# red_bit_decimal= 55
# red_bit_binary= 0b110111
# 2 red lsb = 11
# [+] Pixel : [154,150]
# red_bit_decimal= 2
# red_bit_binary= 0b10
# 2 red lsb = 10
# [+] Pixel : [155,150]
# red_bit_decimal= 21
# red_bit_binary= 0b10101
# 2 red lsb = 01
# [+] Pixel : [156,150]
# red_bit_decimal= 78
# red_bit_binary= 0b1001110
# 2 red lsb = 10
# [+] Pixel : [157,150]
# red_bit_decimal= 96
# red_bit_binary= 0b1100000
# 2 red lsb = 00
# [+] Pixel : [158,150]
# red_bit_decimal= 87
# red_bit_binary= 0b1010111
# 2 red lsb = 11
# [+] Pixel : [159,150]
# red_bit_decimal= 80
# red_bit_binary= 0b1010000
# 2 red lsb = 00
# [+] Pixel : [160,150]
# red_bit_decimal= 68
# red_bit_binary= 0b1000100
# 2 red lsb = 00
# [+] Pixel : [161,150]
# red_bit_decimal= 76
# red_bit_binary= 0b1001100
# 2 red lsb = 00
# [+] Pixel : [162,150]
# red_bit_decimal= 70
# red_bit_binary= 0b1000110
# 2 red lsb = 10
# [+] Pixel : [163,150]
# red_bit_decimal= 80
# red_bit_binary= 0b1010000
# 2 red lsb = 00
# [+] Pixel : [164,150]
# red_bit_decimal= 86
# red_bit_binary= 0b1010110
# 2 red lsb = 10
# [+] Pixel : [165,150]
# red_bit_decimal= 100
# red_bit_binary= 0b1100100
# 2 red lsb = 00
# [+] Pixel : [166,150]
# red_bit_decimal= 90
# red_bit_binary= 0b1011010
# 2 red lsb = 10
# [+] Pixel : [167,150]
# red_bit_decimal= 86
# red_bit_binary= 0b1010110
# 2 red lsb = 10
# [+] Pixel : [168,150]
# red_bit_decimal= 65
# red_bit_binary= 0b1000001
# 2 red lsb = 01
# [+] Pixel : [169,150]
# red_bit_decimal= 48
# red_bit_binary= 0b110000
# 2 red lsb = 00
# [+] Pixel : [170,150]
# red_bit_decimal= 32
# red_bit_binary= 0b100000
# 2 red lsb = 00
# [+] Pixel : [171,150]
# red_bit_decimal= 29
# red_bit_binary= 0b11101
# 2 red lsb = 01
# [+] Pixel : [172,150]
# red_bit_decimal= 26
# red_bit_binary= 0b11010
# 2 red lsb = 10
# [+] Pixel : [173,150]
# red_bit_decimal= 31
# red_bit_binary= 0b11111
# 2 red lsb = 11
# [+] Pixel : [174,150]
# red_bit_decimal= 42
# red_bit_binary= 0b101010
# 2 red lsb = 10
# [+] Pixel : [175,150]
# red_bit_decimal= 54
# red_bit_binary= 0b110110
# 2 red lsb = 10
# [+] Pixel : [176,150]
# red_bit_decimal= 59
# red_bit_binary= 0b111011
# 2 red lsb = 11
# [+] Pixel : [177,150]
# red_bit_decimal= 81
# red_bit_binary= 0b1010001
# 2 red lsb = 01
# [+] Pixel : [178,150]
# red_bit_decimal= 94
# red_bit_binary= 0b1011110
# 2 red lsb = 10
# [+] Pixel : [179,150]
# red_bit_decimal= 91
# red_bit_binary= 0b1011011
# 2 red lsb = 11
# [+] Pixel : [180,150]
# red_bit_decimal= 81
# red_bit_binary= 0b1010001
# 2 red lsb = 01
# [+] Pixel : [181,150]
# red_bit_decimal= 69
# red_bit_binary= 0b1000101
# 2 red lsb = 01
# [+] Pixel : [182,150]
# red_bit_decimal= 68
# red_bit_binary= 0b1000100
# 2 red lsb = 00
# [+] Pixel : [183,150]
# red_bit_decimal= 82
# red_bit_binary= 0b1010010
# 2 red lsb = 10
# [+] Pixel : [184,150]
# red_bit_decimal= 78
# red_bit_binary= 0b1001110
# 2 red lsb = 10
# [+] Pixel : [185,150]
# red_bit_decimal= 80
# red_bit_binary= 0b1010000
# 2 red lsb = 00
# [+] Pixel : [186,150]
# red_bit_decimal= 78
# red_bit_binary= 0b1001110
# 2 red lsb = 10
# [+] Pixel : [187,150]
# red_bit_decimal= 82
# red_bit_binary= 0b1010010
# 2 red lsb = 10
# [+] Pixel : [188,150]
# red_bit_decimal= 87
# red_bit_binary= 0b1010111
# 2 red lsb = 11
# [+] Pixel : [189,150]
# red_bit_decimal= 84
# red_bit_binary= 0b1010100
# 2 red lsb = 00
# [+] Pixel : [190,150]
# red_bit_decimal= 78
# red_bit_binary= 0b1001110
# 2 red lsb = 10
# [+] Pixel : [191,150]
# red_bit_decimal= 79
# red_bit_binary= 0b1001111
# 2 red lsb = 11
# [+] Pixel : [192,150]
# red_bit_decimal= 86
# red_bit_binary= 0b1010110
# 2 red lsb = 10
# [+] Pixel : [193,150]
# red_bit_decimal= 15
# red_bit_binary= 0b1111
# 2 red lsb = 11
# [+] Pixel : [194,150]
# red_bit_decimal= 0
# red_bit_binary= 0b0
# 2 red lsb = b0
# [+] Pixel : [195,150]
# red_bit_decimal= 42
# red_bit_binary= 0b101010
# 2 red lsb = 10
# [+] Pixel : [196,150]
# red_bit_decimal= 135
# red_bit_binary= 0b10000111
# 2 red lsb = 11
# [+] Pixel : [197,150]
# red_bit_decimal= 211
# red_bit_binary= 0b11010011
# 2 red lsb = 11
# [+] Pixel : [198,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [199,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [200,150]
# red_bit_decimal= 246
# red_bit_binary= 0b11110110
# 2 red lsb = 10
# [+] Pixel : [201,150]
# red_bit_decimal= 245
# red_bit_binary= 0b11110101
# 2 red lsb = 01
# [+] Pixel : [202,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [203,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [204,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [205,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [206,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [207,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [208,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [209,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [210,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [211,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [212,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [213,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [214,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [215,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [216,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [217,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [218,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [219,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [220,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [221,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [222,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [223,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [224,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [225,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [226,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [227,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [228,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [229,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [230,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [231,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [232,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [233,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [234,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [235,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [236,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [237,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [238,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [239,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [240,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [241,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [242,150]
# red_bit_decimal= 250
# red_bit_binary= 0b11111010
# 2 red lsb = 10
# [+] Pixel : [243,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [244,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [245,150]
# red_bit_decimal= 250
# red_bit_binary= 0b11111010
# 2 red lsb = 10
# [+] Pixel : [246,150]
# red_bit_decimal= 228
# red_bit_binary= 0b11100100
# 2 red lsb = 00
# [+] Pixel : [247,150]
# red_bit_decimal= 78
# red_bit_binary= 0b1001110
# 2 red lsb = 10
# [+] Pixel : [248,150]
# red_bit_decimal= 19
# red_bit_binary= 0b10011
# 2 red lsb = 11
# [+] Pixel : [249,150]
# red_bit_decimal= 19
# red_bit_binary= 0b10011
# 2 red lsb = 11
# [+] Pixel : [250,150]
# red_bit_decimal= 16
# red_bit_binary= 0b10000
# 2 red lsb = 00
# [+] Pixel : [251,150]
# red_bit_decimal= 97
# red_bit_binary= 0b1100001
# 2 red lsb = 01
# [+] Pixel : [252,150]
# red_bit_decimal= 211
# red_bit_binary= 0b11010011
# 2 red lsb = 11
# [+] Pixel : [253,150]
# red_bit_decimal= 248
# red_bit_binary= 0b11111000
# 2 red lsb = 00
# [+] Pixel : [254,150]
# red_bit_decimal= 247
# red_bit_binary= 0b11110111
# 2 red lsb = 11
# [+] Pixel : [255,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [256,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [257,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [258,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [259,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [260,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [261,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [262,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [263,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [264,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [265,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [266,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [267,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [268,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [269,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [270,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [271,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [272,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [273,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [274,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [275,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [276,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [277,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [278,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [279,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [280,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [281,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [282,150]
# red_bit_decimal= 245
# red_bit_binary= 0b11110101
# 2 red lsb = 01
# [+] Pixel : [283,150]
# red_bit_decimal= 242
# red_bit_binary= 0b11110010
# 2 red lsb = 10
# [+] Pixel : [284,150]
# red_bit_decimal= 164
# red_bit_binary= 0b10100100
# 2 red lsb = 00
# [+] Pixel : [285,150]
# red_bit_decimal= 147
# red_bit_binary= 0b10010011
# 2 red lsb = 11
# [+] Pixel : [286,150]
# red_bit_decimal= 139
# red_bit_binary= 0b10001011
# 2 red lsb = 11
# [+] Pixel : [287,150]
# red_bit_decimal= 132
# red_bit_binary= 0b10000100
# 2 red lsb = 00
# [+] Pixel : [288,150]
# red_bit_decimal= 142
# red_bit_binary= 0b10001110
# 2 red lsb = 10
# [+] Pixel : [289,150]
# red_bit_decimal= 151
# red_bit_binary= 0b10010111
# 2 red lsb = 11
# [+] Pixel : [290,150]
# red_bit_decimal= 215
# red_bit_binary= 0b11010111
# 2 red lsb = 11
# [+] Pixel : [291,150]
# red_bit_decimal= 231
# red_bit_binary= 0b11100111
# 2 red lsb = 11
# [+] Pixel : [292,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [293,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [294,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [295,150]
# red_bit_decimal= 229
# red_bit_binary= 0b11100101
# 2 red lsb = 01
# [+] Pixel : [296,150]
# red_bit_decimal= 228
# red_bit_binary= 0b11100100
# 2 red lsb = 00
# [+] Pixel : [297,150]
# red_bit_decimal= 229
# red_bit_binary= 0b11100101
# 2 red lsb = 01
# [+] Pixel : [298,150]
# red_bit_decimal= 232
# red_bit_binary= 0b11101000
# 2 red lsb = 00
# [+] Pixel : [299,150]
# red_bit_decimal= 231
# red_bit_binary= 0b11100111
# 2 red lsb = 11
# [+] Pixel : [300,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [301,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [302,150]
# red_bit_decimal= 229
# red_bit_binary= 0b11100101
# 2 red lsb = 01
# [+] Pixel : [303,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [304,150]
# red_bit_decimal= 233
# red_bit_binary= 0b11101001
# 2 red lsb = 01
# [+] Pixel : [305,150]
# red_bit_decimal= 233
# red_bit_binary= 0b11101001
# 2 red lsb = 01
# [+] Pixel : [306,150]
# red_bit_decimal= 234
# red_bit_binary= 0b11101010
# 2 red lsb = 10
# [+] Pixel : [307,150]
# red_bit_decimal= 237
# red_bit_binary= 0b11101101
# 2 red lsb = 01
# [+] Pixel : [308,150]
# red_bit_decimal= 235
# red_bit_binary= 0b11101011
# 2 red lsb = 11
# [+] Pixel : [309,150]
# red_bit_decimal= 231
# red_bit_binary= 0b11100111
# 2 red lsb = 11
# [+] Pixel : [310,150]
# red_bit_decimal= 228
# red_bit_binary= 0b11100100
# 2 red lsb = 00
# [+] Pixel : [311,150]
# red_bit_decimal= 230
# red_bit_binary= 0b11100110
# 2 red lsb = 10
# [+] Pixel : [312,150]
# red_bit_decimal= 232
# red_bit_binary= 0b11101000
# 2 red lsb = 00
# [+] Pixel : [313,150]
# red_bit_decimal= 223
# red_bit_binary= 0b11011111
# 2 red lsb = 11
# [+] Pixel : [314,150]
# red_bit_decimal= 220
# red_bit_binary= 0b11011100
# 2 red lsb = 00
# [+] Pixel : [315,150]
# red_bit_decimal= 225
# red_bit_binary= 0b11100001
# 2 red lsb = 01
# [+] Pixel : [316,150]
# red_bit_decimal= 226
# red_bit_binary= 0b11100010
# 2 red lsb = 10
# [+] Pixel : [317,150]
# red_bit_decimal= 218
# red_bit_binary= 0b11011010
# 2 red lsb = 10
# [+] Pixel : [318,150]
# red_bit_decimal= 192
# red_bit_binary= 0b11000000
# 2 red lsb = 00
# [+] Pixel : [319,150]
# red_bit_decimal= 161
# red_bit_binary= 0b10100001
# 2 red lsb = 01
# [+] Pixel : [320,150]
# red_bit_decimal= 124
# red_bit_binary= 0b1111100
# 2 red lsb = 00
# [+] Pixel : [321,150]
# red_bit_decimal= 104
# red_bit_binary= 0b1101000
# 2 red lsb = 00
# [+] Pixel : [322,150]
# red_bit_decimal= 90
# red_bit_binary= 0b1011010
# 2 red lsb = 10
# [+] Pixel : [323,150]
# red_bit_decimal= 57
# red_bit_binary= 0b111001
# 2 red lsb = 01
# [+] Pixel : [324,150]
# red_bit_decimal= 22
# red_bit_binary= 0b10110
# 2 red lsb = 10
# [+] Pixel : [325,150]
# red_bit_decimal= 4
# red_bit_binary= 0b100
# 2 red lsb = 00
# [+] Pixel : [326,150]
# red_bit_decimal= 26
# red_bit_binary= 0b11010
# 2 red lsb = 10
# [+] Pixel : [327,150]
# red_bit_decimal= 91
# red_bit_binary= 0b1011011
# 2 red lsb = 11
# [+] Pixel : [328,150]
# red_bit_decimal= 242
# red_bit_binary= 0b11110010
# 2 red lsb = 10
# [+] Pixel : [329,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [330,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [331,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [332,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [333,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [334,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [335,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [336,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [337,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [338,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [339,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [340,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [341,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [342,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [343,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [344,150]
# red_bit_decimal= 254
# red_bit_binary= 0b11111110
# 2 red lsb = 10
# [+] Pixel : [345,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [346,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [347,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [348,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [349,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [350,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [351,150]
# red_bit_decimal= 237
# red_bit_binary= 0b11101101
# 2 red lsb = 01
# [+] Pixel : [352,150]
# red_bit_decimal= 131
# red_bit_binary= 0b10000011
# 2 red lsb = 11
# [+] Pixel : [353,150]
# red_bit_decimal= 44
# red_bit_binary= 0b101100
# 2 red lsb = 00
# [+] Pixel : [354,150]
# red_bit_decimal= 7
# red_bit_binary= 0b111
# 2 red lsb = 11
# [+] Pixel : [355,150]
# red_bit_decimal= 11
# red_bit_binary= 0b1011
# 2 red lsb = 11
# [+] Pixel : [356,150]
# red_bit_decimal= 9
# red_bit_binary= 0b1001
# 2 red lsb = 01
# [+] Pixel : [357,150]
# red_bit_decimal= 84
# red_bit_binary= 0b1010100
# 2 red lsb = 00
# [+] Pixel : [358,150]
# red_bit_decimal= 195
# red_bit_binary= 0b11000011
# 2 red lsb = 11
# [+] Pixel : [359,150]
# red_bit_decimal= 249
# red_bit_binary= 0b11111001
# 2 red lsb = 01
# [+] Pixel : [360,150]
# red_bit_decimal= 247
# red_bit_binary= 0b11110111
# 2 red lsb = 11
# [+] Pixel : [361,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [362,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [363,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [364,150]
# red_bit_decimal= 251
# red_bit_binary= 0b11111011
# 2 red lsb = 11
# [+] Pixel : [365,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [366,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [367,150]
# red_bit_decimal= 253
# red_bit_binary= 0b11111101
# 2 red lsb = 01
# [+] Pixel : [368,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [369,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [370,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [371,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [372,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [373,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [374,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [375,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [376,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [377,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [378,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [379,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [380,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [381,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [382,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [383,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [384,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [385,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [386,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [387,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [388,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [389,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11
# [+] Pixel : [390,150]
# red_bit_decimal= 255
# red_bit_binary= 0b11111111
# 2 red lsb = 11

# %% [markdown]
# #### runs Embed to embed both kinds of watermark into image, take grayscale images for instance, where the number of gray levels is 256
